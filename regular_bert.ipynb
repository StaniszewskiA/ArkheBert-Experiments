# %%
import pandas as pd

diorisis_df = pd.read_excel('output.xlsx')

print(diorisis_df.columns)
# Out:
# Index(['B_Word', 'B_Lemma', 'I_Lemma', 'B_Analysis'], dtype='object')

# %%
import os
from tqdm import tqdm_notebook as tqdm
import numpy as np
import torch
import torch.nn as nn
from torch.utils import data
import torch.optim as optim

# %%
import torch
from transformers import BertTokenizer, BertForTokenClassification

# %%
b_lemmas: list[str] = diorisis_df['B_Lemma'].tolist()
i_lemmas: list[str] = diorisis_df['I_Lemma'].tolist()

# %%
i_lemmas
# Out:
# ['proper',
#  'preposition',
#  'noun',
#  'adjective',
#  'proper',
#  'article',
#  'noun',
#  'noun',
#  'proper',
#  'article',
#  'adjective',
#  'proper',
#  'article',
#  'noun',
#  'noun',
#  'adjective',
#  'noun',
#  'preposition',
#  'noun',
#  'adjective',
#  'adverb',
#  'verb',
#  'article',
#  'noun',
#  'adverb',
#  'particle',
#  'article',
#  'noun',
#  'preposition',
#  'noun',
#  'preposition',
#  'adjective',
#  'verb',
#  'noun',
#  'adjective',
#  'verb',
#  'conjunction',
#  'article',
#  'noun',
#  'adverb',
#  'verb',
#  'conjunction',
#  'verb',
#  'article',
#  'noun',
#  'adjective',
#  'noun',
#  'conjunction',
#  'verb',
#  'particle',
#  'adverb',
#  'article',
#  'noun',
#  'preposition',
#  'noun',
#  'verb',
#  'particle',
#  'article',
#  'noun',
#  'preposition',
#  'article',
#  'noun',
#  'adverb',
#  'verb',
#  'preposition',
#  'adjective',
#  'noun',
#  'noun',
#  'verb',
#  'pronoun',
#  'article',
#  'article',
#  'proper',
#  'noun',
#  nan,
#  'pronoun',
#  'article',
#  'proper',
#  'verb',
#  'verb',
#  'particle',
#  'conjunction',
#  'article',
#  'adjective',
#  'adjective',
#  'conjunction',
#  'verb',
#  'article',
#  'noun',
#  'verb',
#  'noun',
#  'verb',
#  'noun',
#  'adverb',
#  'conjunction',
#  'noun',
#  'proper',
#  'article',
#  'noun',
#  'proper',
#  'article',
#  'noun',
#  'proper',
#  'article',
#  'noun',
#  'preposition',
#  'article',
#  'noun',
#  'noun',
#  'conjunction',
#  'noun',
#  'noun',
#  'preposition',
#  'article',
#  'noun',
#  'noun',
#  'verb',
#  'conjunction',
#  'article',
#  'noun',
#  'noun',
#  'noun',
#  'verb',
#  'preposition',
#  'proper',
#  'article',
#  'noun',
#  'verb',
#  'verb',
#  'adjective',
#  'adjective',
#  'article',
#  'noun',
#  'adjective',
#  'pronoun',
#  'verb',
#  'noun',
#  'conjunction',
#  'noun',
#  'adverb',
#  'article',
#  'adjective',
#  'adjective',
#  'article',
#  'noun',
#  'verb',
#  'article',
#  'noun',
#  'article',
#  'noun',
#  'conjunction',
#  'verb',
#  'article',
#  'adjective',
#  'noun',
#  'article',
#  'article',
#  'noun',
#  'noun',
#  'verb',
#  'article',
#  'noun',
#  'preposition',
#  'article',
#  'noun',
#  'conjunction',
#  'article',
#  'noun',
#  'conjunction',
#  'article',
#  'noun',
#  'adverb',
#  'adjective',
#  'verb',
#  'adjective',
#  'article',
#  'adjective',
#  'article',
#  'article',
#  'noun',
#  'noun',
#  'verb',
#  'article',
#  'noun',
#  'adjective',
#  'verb',
#  'article',
#  'noun',
#  'noun',
#  'adverb',
#  'particle',
#  'article',
#  'article',
#  'noun',
#  'noun',
#  'article',
#  'noun',
#  'verb',
#  'article',
#  'particle',
#  'noun',
#  'article',
#  'noun',
#  'preposition',
#  'article',
#  'noun',
#  'article',
#  'noun',
#  'adverb',
#  'verb',
#  'noun',
#  'conjunction',
#  'noun',
#  'conjunction',
#  nan,
#  'noun',
#  'particle',
#  'preposition',
#  'adjective',
#  'verb',
#  'article',
#  'noun',
#  'article',
#  'particle',
#  'verb',
#  'adverb',
#  'preposition',
#  'article',
#  'noun',
#  'article',
#  'particle',
#  'article',
#  'adjective',
#  'conjunction',
#  'article',
#  'noun',
#  'verb',
#  'adjective',
#  'pronoun',
#  'verb',
#  'adjective',
#  'verb',
#  'conjunction',
#  'preposition',
#  'adjective',
#  'noun',
#  'verb',
#  'conjunction',
#  'verb',
#  'article',
#  'adjective',
#  'article',
#  'noun',
#  'preposition',
#  'particle',
#  'pronoun',
#  'article',
#  'noun',
#  'noun',
#  'preposition',
#  'article',
#  'preposition',
#  'noun',
#  'article',
#  'noun',
#  'noun',
#  'article',
#  'noun',
#  'verb',
#  'article',
#  'noun',
#  'article',
#  'noun',
#  'article',
#  'noun',
#  'conjunction',
#  'noun',
#  'conjunction',
#  'noun',
#  'noun',
#  'preposition',
#  'article',
#  'noun',
#  'verb',
#  'noun',
#  'preposition',
#  'article',
#  'noun',
#  'verb',
#  'article',
#  'noun',
#  'adjective',
#  'verb',
#  'article',
#  'particle',
#  'adverb',
#  'article',
#  'adjective',
#  'article',
#  'particle',
#  'adjective',
#  'article',
#  'noun',
#  'article',
#  'particle',
#  'noun',
#  'preposition',
#  'noun',
#  'verb',
#  'article',
#  'adjective',
#  'article',
#  'noun',
#  'adjective',
#  'verb',
#  'article',
#  'noun',
#  'article',
#  'noun',
#  'verb',
#  'preposition',
#  'article',
#  'noun',
#  'adjective',
#  'verb',
#  'article',
#  'noun',
#  'adverb',
#  'verb',
#  'preposition',
#  'noun',
#  'verb',
#  'conjunction',
#  'noun',
#  'article',
#  'noun',
#  'conjunction',
#  'preposition',
#  'article',
#  'noun',
#  'verb',
#  'verb',
#  'adjective',
#  'article',
#  'noun',
#  'adjective',
#  'adjective',
#  'adverb',
#  'article',
#  'noun',
#  'verb',
#  'article',
#  'noun',
#  'verb',
#  'particle',
#  'verb',
#  'particle',
#  'conjunction',
#  'preposition',
#  'article',
#  'noun',
#  'verb',
#  'verb',
#  'particle',
#  'article',
#  'noun',
#  'verb',
#  'article',
#  'particle',
#  'noun',
#  'article',
#  'noun',
#  'adjective',
#  'article',
#  'particle',
#  'particle',
#  'preposition',
#  'article',
#  'noun',
#  'adjective',
#  'adjective',
#  'particle',
#  'article',
#  'preposition',
#  'article',
#  'noun',
#  'noun',
#  'verb',
#  'conjunction',
#  'noun',
#  'conjunction',
#  'noun',
#  'article',
#  'noun',
#  'article',
#  'noun',
#  'verb',
#  'article',
#  'noun',
#  'verb',
#  'article',
#  'noun',
#  'article',
#  'noun',
#  'verb',
#  'conjunction',
#  'preposition',
#  'article',
#  'noun',
#  'verb',
#  'preposition',
#  'article',
#  'noun',
#  'noun',
#  'preposition',
#  'adjective',
#  'article',
#  'noun',
#  'verb',
#  'article',
#  'noun',
#  'verb',
#  'conjunction',
#  'adjective',
#  'verb',
#  'article',
#  'noun',
#  'adverb',
#  'verb',
#  'article',
#  'noun',
#  'verb',
#  'article',
#  'noun',
#  nan,
#  'adjective',
#  'verb',
#  'article',
#  'noun',
#  'article',
#  'noun',
#  'adverb',
#  nan,
#  'adverb',
#  'preposition',
#  'noun',
#  'preposition',
#  'adjective',
#  'verb',
#  'article',
#  'noun',
#  'article',
#  'noun',
#  'article',
#  'noun',
#  'verb',
#  'adverb',
#  'adjective',
#  'verb',
#  'conjunction',
#  'particle',
#  'article',
#  'noun',
#  'verb',
#  'pronoun',
#  'adverb',
#  'preposition',
#  'article',
#  'article',
#  'noun',
#  'verb',
#  'verb',
#  'adjective',
#  'preposition',
#  'article',
#  'noun',
#  'article',
#  'noun',
#  'preposition',
#  'noun',
#  'adverb',
#  'verb',
#  'noun',
#  'article',
#  'adjective',
#  'article',
#  'adjective',
#  'adjective',
#  'article',
#  'adjective',
#  'article',
#  'noun',
#  'adjective',
#  'article',
#  'particle',
#  'adjective',
#  'preposition',
#  'article',
#  'noun',
#  'verb',
#  'adjective',
#  'noun',
#  'noun',
#  'verb',
#  'noun',
#  'adjective',
#  'article',
#  'adjective',
#  'preposition',
#  'noun',
#  'verb',
#  'verb',
#  'noun',
#  'article',
#  'noun',
#  'adverb',
#  'verb',
#  'article',
#  'verb',
#  'noun',
#  'article',
#  'adjective',
#  'conjunction',
#  'article',
#  'noun',
#  'verb',
#  'conjunction',
#  'verb',
#  'article',
#  'adjective',
#  'noun',
#  'article',
#  'adjective',
#  'article',
#  'noun',
#  'noun',
#  'verb',
#  'article',
#  'particle',
#  'preposition',
#  'noun',
#  'article',
#  'particle',
#  'preposition',
#  'noun',
#  'verb',
#  'particle',
#  'noun',
#  'adverb',
#  'preposition',
#  'article',
#  'noun',
#  'noun',
#  'noun',
#  'article',
#  'noun',
#  'verb',
#  'article',
#  'particle',
#  'noun',
#  'article',
#  'noun',
#  'adverb',
#  'verb',
#  'verb',
#  'conjunction',
#  'verb',
#  'pronoun',
#  'noun',
#  'article',
#  'noun',
#  'article',
#  'particle',
#  'verb',
#  'article',
#  'noun',
#  'adjective',
#  'verb',
#  'noun',
#  'adverb',
#  'noun',
#  'article',
#  'noun',
#  'verb',
#  'preposition',
#  'particle',
#  'article',
#  'noun',
#  'verb',
#  'adjective',
#  'verb',
#  'noun',
#  'verb',
#  'particle',
#  'pronoun',
#  'verb',
#  'conjunction',
#  'article',
#  'noun',
#  'noun',
#  'verb',
#  'article',
#  'noun',
#  'noun',
#  'adjective',
#  'noun',
#  'verb',
#  'article',
#  'noun',
#  'verb',
#  'noun',
#  'verb',
#  'article',
#  'noun',
#  'verb',
#  'particle',
#  'conjunction',
#  'preposition',
#  'article',
#  'proper',
#  'conjunction',
#  'verb',
#  'adverb',
#  'pronoun',
#  'verb',
#  'pronoun',
#  'preposition',
#  'pronoun',
#  'verb',
#  'noun',
#  'pronoun',
#  'particle',
#  'conjunction',
#  'adjective',
#  'particle',
#  'verb',
#  'article',
#  'noun',
#  'adverb',
#  'particle',
#  'verb',
#  'adjective',
#  'adjective',
#  'verb',
#  'article',
#  'verb',
#  'article',
#  'noun',
#  'noun',
#  'conjunction',
#  'adjective',
#  'verb',
#  'verb',
#  'noun',
#  'noun',
#  'conjunction',
#  'noun',
#  'conjunction',
#  'noun',
#  'pronoun',
#  'pronoun',
#  'verb',
#  'noun',
#  'conjunction',
#  'pronoun',
#  'verb',
#  'pronoun',
#  'pronoun',
#  'particle',
#  'verb',
#  'verb',
#  'adjective',
#  'noun',
#  'preposition',
#  'noun',
#  'verb',
#  'conjunction',
#  'pronoun',
#  'verb',
#  'verb',
#  'adjective',
#  'conjunction',
#  'particle',
#  'verb',
#  'pronoun',
#  'article',
#  'noun',
#  'adverb',
#  'adverb',
#  'verb',
#  'article',
#  'article',
#  'noun',
#  'noun',
#  'proper',
#  'verb',
#  'verb',
#  'noun',
#  'article',
#  'particle',
#  'adjective',
#  'noun',
#  'verb',
#  'conjunction',
#  'verb',
#  'interjection',
#  'adjective',
#  'verb',
#  'preposition',
#  'article',
#  'proper',
#  'conjunction',
#  'article',
#  'noun',
#  'pronoun',
#  'pronoun',
#  'adverb',
#  'verb',
#  'conjunction',
#  'conjunction',
#  'noun',
#  'verb',
#  'conjunction',
#  'pronoun',
#  'particle',
#  'verb',
#  'verb',
#  'particle',
#  'pronoun',
#  'conjunction',
#  'preposition',
#  'pronoun',
#  'noun',
#  'verb',
#  'noun',
#  'adverb',
#  'noun',
#  'particle',
#  'verb',
#  'adjective',
#  'conjunction',
#  'adjective',
#  'verb',
#  'particle',
#  'noun',
#  'adjective',
#  'particle',
#  'conjunction',
#  'adverb',
#  'adjective',
#  'preposition',
#  'adjective',
#  'adverb',
#  'verb',
#  'verb',
#  'verb',
#  'particle',
#  'pronoun',
#  'preposition',
#  'pronoun',
#  'noun',
#  'adjective',
#  'conjunction',
#  'pronoun',
#  'verb',
#  'adjective',
#  'pronoun',
#  'verb',
#  'article',
#  'article',
#  'noun',
#  'noun',
#  'adverb',
#  nan,
#  'particle',
#  'article',
#  'noun',
#  'adjective',
#  'conjunction',
#  'noun',
#  'adjective',
#  'adjective',
#  'article',
#  nan,
#  'particle',
#  'verb',
#  'article',
#  'verb',
#  'adverb',
#  'pronoun',
#  'proper',
#  'noun',
#  'proper',
#  'adjective',
#  'adjective',
#  'proper',
#  'noun',
#  'proper',
#  'adjective',
#  'noun',
#  'proper',
#  'adverb',
#  'adjective',
#  'particle',
#  'adjective',
#  'adverb',
#  'adjective',
#  'noun',
#  'adjective',
#  'noun',
#  'article',
#  'particle',
#  'noun',
#  'article',
#  'particle',
#  'verb',
#  'proper',
#  'article',
#  'particle',
#  'adjective',
#  'noun',
#  'proper',
#  'article',
#  'particle',
#  'particle',
#  'article',
#  'adjective',
#  'noun',
#  'verb',
#  'preposition',
#  'proper',
#  'adjective',
#  'particle',
#  'article',
#  'article',
#  'noun',
#  'adjective',
#  'verb',
#  'pronoun',
#  'article',
#  'particle',
#  'adjective',
#  'noun',
#  'preposition',
#  'proper',
#  'verb',
#  'article',
#  'particle',
#  'noun',
#  'adverb',
#  'verb',
#  'article',
#  'adjective',
#  'preposition',
#  'adjective',
#  'particle',
#  'pronoun',
#  'verb',
#  'verb',
#  'particle',
#  'article',
#  'noun',
#  'noun',
#  'adjective',
#  'preposition',
#  'pronoun',
#  'noun',
#  'pronoun',
#  'proper',
#  'verb',
#  'conjunction',
#  'verb',
#  'particle',
#  'article',
#  'noun',
#  'verb',
#  'pronoun',
#  'adjective',
#  'article',
#  'particle',
#  'proper',
#  'article',
#  'noun',
#  'verb',
#  'adjective',
#  'verb',
#  'pronoun',
#  'noun',
#  'verb',
#  'particle',
#  'article',
#  'noun',
#  'adverb',
#  'noun',
#  'article',
#  'verb',
#  'adverb',
#  'verb',
#  'adverb',
#  'conjunction',
#  'verb',
#  'conjunction',
#  'verb',
#  'adverb',
#  'particle',
#  'verb',
#  'verb',
#  'verb',
#  'adverb',
#  'conjunction',
#  'adjective',
#  'verb',
#  'verb',
#  'article',
#  'particle',
#  'particle',
#  'adjective',
#  'conjunction',
#  'adjective',
#  'verb',
#  'article',
#  'noun',
#  'adverb',
#  'verb',
#  'conjunction',
#  'verb',
#  'article',
#  'particle',
#  'preposition',
#  'article',
#  'verb',
#  'verb',
#  'verb',
#  'preposition',
#  'adjective',
#  'verb',
#  'article',
#  'adjective',
#  'article',
#  'noun',
#  'conjunction',
#  'particle',
#  'verb',
#  'adjective',
#  'noun',
#  'preposition',
#  'article',
#  'verb',
#  'conjunction',
#  'verb',
#  'article',
#  'noun',
#  'preposition',
#  'adverb',
#  'verb',
#  'article',
#  'adjective',
#  'verb',
#  'article',
#  'noun',
#  'article',
#  'noun',
#  'noun',
#  'verb',
#  'verb',
#  'article',
#  'noun',
#  'article',
#  'adjective',
#  'noun',
#  'preposition',
#  'noun',
#  'adjective',
#  'particle',
#  'adverb',
#  'article',
#  'adverb',
#  'adjective',
#  'verb',
#  'particle',
#  'pronoun',
#  'noun',
#  'adjective',
#  'conjunction',
#  'adverb',
#  'article',
#  'noun',
#  'adjective',
#  'noun',
#  'preposition',
#  'noun',
#  'adjective',
#  'noun',
#  'noun',
#  'article',
#  'noun',
#  'noun',
#  'verb',
#  'article',
#  'adjective',
#  ...]

# %%
tagged_data = diorisis_df[['B_Lemma', 'I_Lemma']]
tagged_sents = [tuple(x) for x in tagged_data.values]

# %%
tags = list(set(tag for _, tag in tagged_sents))
tags = ["<pad>"] + tags

tag2idx = {tag: idx for idx, tag in enumerate(tags)}
idx2tag = {idx: tag for idx, tag in enumerate(tags)}

# %%
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(tagged_sents, test_size=0.2)
len(train_data), len(test_data)
# Out:
# (33329, 8333)

# %% [markdown]
# Data loader

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-cased', do_lower_case=False)

class PosDataset(data.Dataset):
    def __init__(self, tagged_sents):
        sents, tags_li = [], []
        for b_lemma, i_lemma in tagged_sents:
            words = [b_lemma]
            tags = [i_lemma]
            sents.append(["[CLS]"] + words + ["[SEP]"])
            tags_li.append(["<pad>"] + tags + ["<pad>"])
        self.sents, self.tags_li = sents, tags_li

    def __len__(self):
        return len(self.sents)

    def __getitem__(self, idx):
        words, tags = self.sents[idx], self.tags_li[idx]

        x, y = [], []
        is_heads = []
        for w, t in zip(words, tags):
            tokens = tokenizer.tokenize(w) if w not in ("[CLS]", "[SEP]") else [w]
            xx = tokenizer.convert_tokens_to_ids(tokens)

            is_head = [1] + [0]*(len(tokens) - 1)

            t = [t] + ["<pad>"] * (len(tokens) - 1)
            yy = [tag2idx[each] for each in t]

            x.extend(xx)
            is_heads.extend(is_head)
            y.extend(yy)

        assert len(x) == len(y) == len(is_heads), "len(x)={}, len(y)={}, len(is_heads)={}".format(len(x), len(y), len(is_heads))

        seqlen = len(y)

        words = " ".join(words)
        tags = " ".join(tags)
        return words, x, is_heads, tags, y, seqlen

def pad(batch):
    f = lambda x: [sample[x] for sample in batch]
    words = f(0)
    is_heads = f(2)
    tags = f(3)
    seqlens = f(-1)
    maxlen = np.array(seqlens).max()

    f = lambda x, seqlen: [sample[x] + [0] * (seqlen - len(sample[x])) for sample in batch]
    x = f(1, maxlen)
    y = f(-2, maxlen)

    f = torch.LongTensor

    return words, f(x), is_heads, tags, f(y), seqlens

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
from pytorch_pretrained_bert import BertModel

# %% [markdown]
# Model

# %%
class BertNet(nn.Module):
    def __init__(self, vocab_size=None):
        super().__init__()
        self.bert = BertModel.from_pretrained('bert-base-cased')

        self.fc = nn.Linear(768, vocab_size)
        self.device = device
    
    def forward(self, x, y):
        x = x.to(device)
        y = y.to(device)

        if self.training:
            self.bert.train()
            encoded_layers, _ = self.bert(x)
            enc = encoded_layers[-1]
        else:
            self.bert.eval()
            with torch.no_grad():
                encoded_layers, _ = self.bert(x)
                enc = encoded_layers[-1]
        
        logits = self.fc(enc)
        y_hat = logits.argmax(-1)
        return logits, y, y_hat

# %%
from tqdm import tqdm

def train(model, iterator, optimizer, criterion):
    model.train()
    for i, batch in enumerate(tqdm(iterator, desc="Training Progress")):
        words, x, is_heads, tags, y, seqlens = batch
        _y = y
        optimizer.zero_grad()
        logits, y, _ = model(x, y)

        logits = logits.view(-1, logits.shape[-1])
        y = y.view(-1)

        loss = criterion(logits, y)
        loss.backward()

        optimizer.step()

        if i % 10 == 0: # monitoring
            print("step: {}, loss: {}".format(i, loss.item()))

# %%
def eval(model, iterator):
    model.eval()

    Words, Is_heads, Tags, Y, Y_hat = [], [], [], [], []
    with torch.no_grad():
        for i, batch in enumerate(iterator):
            words, x, is_heads, tags, y, seqlens = batch

            _, _, y_hat = model(x, y)  # y_hat: (N, T)

            Words.extend(words)
            Is_heads.extend(is_heads)
            Tags.extend(tags)
            Y.extend(y.numpy().tolist())
            Y_hat.extend(y_hat.cpu().numpy().tolist())

    ## gets results and save
    with open("result", 'w') as fout:
        for words, is_heads, tags, y_hat in zip(Words, Is_heads, Tags, Y_hat):
            y_hat = [hat for head, hat in zip(is_heads, y_hat) if head == 1]
            preds = [idx2tag[hat] for hat in y_hat]
            assert len(preds)==len(words.split())==len(tags.split())
            for w, t, p in zip(words.split()[1:-1], tags.split()[1:-1], preds[1:-1]):
                fout.write("{} {} {}\n".format(w, t, p))
            fout.write("\n")
            
    ## calc metric
    y_true =  np.array([tag2idx[line.split()[1]] for line in open('result', 'r').read().splitlines() if len(line) > 0])
    y_pred =  np.array([tag2idx[line.split()[2]] for line in open('result', 'r').read().splitlines() if len(line) > 0])

    acc = (y_true==y_pred).astype(np.int32).sum() / len(y_true)

    print("acc=%.2f"%acc)

# %%
model = BertNet(vocab_size=len(tag2idx))
model.to(device)
model = nn.DataParallel(model)

train_dataset = PosDataset(train_data)
eval_dataset = PosDataset(test_data)

train_iter = data.DataLoader(dataset=train_dataset,
                             batch_size=8,
                             shuffle=True,
                             num_workers=1,
                             collate_fn=pad)
test_iter = data.DataLoader(dataset=eval_dataset,
                             batch_size=8,
                             shuffle=False,
                             num_workers=1,
                             collate_fn=pad)

optimizer = optim.Adam(model.parameters(), lr=0.0001)
criterion = nn.CrossEntropyLoss(ignore_index=0)

train(model, train_iter, optimizer, criterion)
eval(model, test_iter)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 model = BertNet(vocab_size=len(tag2idx))
#       2 model.to(device)
#       3 model = nn.DataParallel(model)
#
# Cell In[36], line 4, in BertNet.__init__(self, vocab_size)
#       2 def __init__(self, vocab_size=None):
#       3     super().__init__()
# ----> 4     self.bert = BertModel.from_pretrained('bert-base-cased')
#       6     self.fc = nn.Linear(768, vocab_size)
#       7     self.device = device
#
# File e:\Users\PanSt\OneDrive\Pulpit\Python\Lib\site-packages\pytorch_pretrained_bert\modeling.py:566, in BertPreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     564 # redirect to the cache, if necessary
#     565 try:
# --> 566     resolved_archive_file = cached_path(archive_file, cache_dir=cache_dir)
#     567 except EnvironmentError:
#     568     logger.error(
#     569         "Model name '{}' was not found in model name list ({}). "
#     570         "We assumed '{}' was a path or url but couldn't find any file "
#    (...)
#     573             ', '.join(PRETRAINED_MODEL_ARCHIVE_MAP.keys()),
#     574             archive_file))
#
# File e:\Users\PanSt\OneDrive\Pulpit\Python\Lib\site-packages\pytorch_pretrained_bert\file_utils.py:106, in cached_path(url_or_filename, cache_dir)
#     102 parsed = urlparse(url_or_filename)
#     104 if parsed.scheme in ('http', 'https', 's3'):
#     105     # URL, so get it from the cache (downloading if necessary)
# --> 106     return get_from_cache(url_or_filename, cache_dir)
#     107 elif os.path.exists(url_or_filename):
#     108     # File, and it exists.
#     109     return url_or_filename
#
# File e:\Users\PanSt\OneDrive\Pulpit\Python\Lib\site-packages\pytorch_pretrained_bert\file_utils.py:230, in get_from_cache(url, cache_dir)
#     228     s3_get(url, temp_file)
#     229 else:
# --> 230     http_get(url, temp_file)
#     232 # we are copying the file before closing it, so flush to avoid truncation
#     233 temp_file.flush()
#
# File e:\Users\PanSt\OneDrive\Pulpit\Python\Lib\site-packages\pytorch_pretrained_bert\file_utils.py:172, in http_get(url, temp_file)
#     170 total = int(content_length) if content_length is not None else None
#     171 progress = tqdm(unit="B", total=total)
# --> 172 for chunk in req.iter_content(chunk_size=1024):
#     173     if chunk: # filter out keep-alive new chunks
#     174         progress.update(len(chunk))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File e:\Users\PanSt\OneDrive\Pulpit\Python\Lib\http\client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File e:\Users\PanSt\OneDrive\Pulpit\Python\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File e:\Users\PanSt\OneDrive\Pulpit\Python\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File e:\Users\PanSt\OneDrive\Pulpit\Python\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:
